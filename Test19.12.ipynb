# %%
#GO BACK TO PART D QUESTION 6 PIVOT TABLE !!!!!!!!!!!!

# %%
import pandas as pd
import matplotlib
import seaborn as sns
import numpy as np
from IPython.display import display
import matplotlib.pyplot as plt
import random 

#Test done in test time 
#Part A
#היתרונות של שימוש במידע גולמי הוא שהוא הכי מדוייק שיכול להיות מאחר והוא נלקח ללא שינוים, מצד שני, החסרונות הם הקושי בניתוח ובהסקת המסקנות על המידע שאינו נוח לעבוד איתו

#עלולות לצוץ בעיות שקשורות במידע חסר, וניתן לזהות אותן באמצעות פעולות שמחשבות את כמות המידע בשורה ולתקן באמצעות החלפתן בערך הגיוני או מחיקת השורה כולה

#בתאריך חסר הייתי מכניס את התאריך הממוצע ביחסית לטבלה
#במקום מגורים חסר הייתי משתמש בפונקציית מוד על מנת להחליף את המקום החסר עם המקום המופיע הכי הרבה פעמים
#במקומות שמופיע אותו לקוח מספר פעמים הייתי מוחק את השורות בהן נמצאות פחות מידע, זאת אומרת יותר חוסרים
#במקומות בהם חסרים הציון המספרי הייתי מחליף בממוצע, או בערך המופיע הכי הרבה פעמים, או בחציון

# %%
#Part B
data = [
    {"cust_id": 1, "timestamp": "2024-01-01", "residence": "Tel Aviv", "grade": 8},
    {"cust_id": 2, "timestamp": "2024-01-02", "residence": "Jerusalem", "grade": None},
    {"cust_id": 1, "timestamp": "2024-01-03", "residence": "Tel Aviv", "grade": 8},
    {"cust_id": 3, "timestamp": "2024-01-04", "residence": None, "grade": 7},
    {"cust_id": 2, "timestamp": "2024-01-05", "residence": "Jerusalem", "grade": None}
]

#-

#-

#-

#-
df = pd.DataFrame(data)
df.drop_duplicates(subset = 'cust_id') #inplace = True
df.dropna() #inplace = True
df['grade'].fillna(df['grade'].mean()) #inplace = True

#-
df.groupby('residence')['grade'].mean()
df.apply(lambda x: 3 if x['grade'] == None else 5, axis = 1)
df.apply(lambda x: display(type(x['grade'])), axis = 1)
# Out:
# float
# float
# float
# float
# float
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None
# dtype: object

# %%
#Part C
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#5
#-
tables = [customers, items, orderItem, orders]

for i in tables:
    display(i.info())

#-
for i in tables:
    display(i.describe())

#-
for i in tables:
    display(i.head()) #5 in default
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            500 non-null    int64
#  1   first_name    494 non-null    object
#  2   last_name     494 non-null    object
#  3   gender        447 non-null    object
#  4   age           475 non-null    float64
#  5   nationallity  494 non-null    object
#  6   joining_date  439 non-null    object
#  7   phone_number  500 non-null    object
#  8   email         500 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 35.3+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50 entries, 0 to 49
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 50 non-null     int64
#  1   item_name          50 non-null     object
#  2   item_category      39 non-null     object
#  3   item_price         50 non-null     float64
#  4   stock_quantity     45 non-null     float64
#  5   item_brand         42 non-null     object
#  6   item_availability  50 non-null     bool
# dtypes: bool(1), float64(2), int64(1), object(3)
# memory usage: 2.5+ KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        1000 non-null   int64
#  1   order_id  1000 non-null   int64
#  2   item_id   960 non-null    float64
#  3   quantity  1000 non-null   int64
# dtypes: float64(1), int64(3)
# memory usage: 31.4 KB
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   order_id          600 non-null    int64
#  1   customer_id       555 non-null    float64
#  2   delivery_address  600 non-null    object
#  3   delivery_days     525 non-null    float64
#  4   order_date        600 non-null    object
#  5   payment_method    600 non-null    object
#  6   order_source      600 non-null    object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 32.9+ KB
# None
#                id         age
# count  500.000000  475.000000
# mean   250.500000   44.006316
# std    144.481833   14.813395
# min      1.000000    2.000000
# 25%    125.750000   34.000000
# 50%    250.500000   44.000000
# 75%    375.250000   55.000000
# max    500.000000   84.000000
#              id   item_price  stock_quantity
# count  50.00000    50.000000       45.000000
# mean   25.50000  2222.082600      743.155556
# std    14.57738  1394.005145      332.855071
# min     1.00000   241.540000       14.000000
# 25%    13.25000  1004.360000      550.000000
# 50%    25.50000  1956.220000      704.000000
# 75%    37.75000  3436.830000      971.000000
# max    50.00000  4471.270000     1367.000000
#                 id     order_id     item_id     quantity
# count  1000.000000  1000.000000  960.000000  1000.000000
# mean    500.500000   305.006000   25.746875     3.016000
# std     288.819436   171.251432   14.676686     2.288882
# min       1.000000     1.000000    1.000000     1.000000
# 25%     250.750000   157.000000   13.000000     1.000000
# 50%     500.500000   315.000000   26.000000     2.000000
# 75%     750.250000   450.000000   38.000000     4.000000
# max    1000.000000   599.000000   50.000000     9.000000
#          order_id  customer_id  delivery_days
# count  600.000000   555.000000     525.000000
# mean   300.500000   258.650450       3.899048
# std    173.349358   146.002993       1.075091
# min      1.000000     1.000000       1.000000
# 25%    150.750000   136.000000       3.000000
# 50%    300.500000   256.000000       4.000000
# 75%    450.250000   385.000000       5.000000
# max    600.000000   500.000000       6.000000
#    id first_name  last_name  gender   age nationallity joining_date  \
# 0   1      Eadie     Maffeo  Female  41.0       France   11/01/2022
# 1   2     Hammad  Brewerton    Male  56.0       Isreal   30/09/2022
# 2   3    Terrell       Bris    Male  43.0        India          NaN
# 3   4    Frannie   Morewood    Male  84.0       France   26/05/2021
# 4   5      Sophi      Fleet  Female  33.0       Sweden   19/07/2021
#
#    phone_number                      email
# 0  534-341-9052        emaffeo0@smh.com.au
# 1  999-994-0510  hbrewerton1@discovery.com
# 2  980-455-5208            tbris2@yale.edu
# 3  979-187-1493  fmorewood3@vistaprint.com
# 4  991-853-9984         sfleet4@unicef.org
#    id           item_name                item_category  item_price  \
# 0  26       Action Camera        Photography Equipment     2694.25
# 1  37  Antivirus Software                     Software     4186.62
# 2  11      Blu-Ray Player  Video Players and Recorders     3382.86
# 3  25           Camcorder        Photography Equipment      860.01
# 4   7              Camera        Photography Equipment     2366.72
#
#    stock_quantity item_brand  item_availability
# 0             NaN       Bose              False
# 1             NaN        NaN              False
# 2           704.0       ASUS               True
# 3           870.0       Bose               True
# 4           458.0  Microsoft               True
#    id  order_id  item_id  quantity
# 0   1       337     10.0         2
# 1   2       430     27.0         6
# 2   3       430     36.0         2
# 3   4       508     46.0         1
# 4   5       229     27.0         2
#    order_id  customer_id    delivery_address  delivery_days  order_date  \
# 0         1        477.0  576 Cordelia Place            2.0  2023-12-05
# 1         2         93.0      4664 6th Drive            4.0  2023-08-17
# 2         3        474.0      8766 4th Point            4.0  2023-02-25
# 3         4        333.0       31 Bonner Way            3.0  2023-02-04
# 4         5        436.0   20352 Shelley Way            5.0  2023-06-01
#
#   payment_method order_source
# 0      GIFT_CARD      WEBSITE
# 1           CASH        STORE
# 2          CHECK        STORE
# 3           CASH        STORE
# 4           CASH        STORE

# %%
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#6 

items["info level"] = items.notna().sum(axis = 1)
itemsDuped = items[items.duplicated(subset = "item_name", keep = False)].sort_values("item_name")
itemsDuped = itemsDuped.sort_values(["item_name", "info level"], ascending = False)
kept = itemsDuped.drop_duplicates("item_name")
removed = itemsDuped.drop(index = kept.index)
items.drop(removed.index, inplace = True)
items
# Out:
#     id            item_name                   item_category  item_price  \
# 0   26        Action Camera           Photography Equipment     2694.25
# 1   37   Antivirus Software                        Software     4186.62
# 2   11       Blu-Ray Player     Video Players and Recorders     3382.86
# 3   25            Camcorder           Photography Equipment      860.01
# 4    7               Camera           Photography Equipment     2366.72
# 7   18     Computer Monitor       Computers and Accessories     4076.35
# 8   27          Dash Camera           Photography Equipment     1283.99
# 9    3              Desktop       Computers and Accessories     1121.84
# 11  24                Drone        Televisions and Displays     4449.99
# 14  21  External Hard Drive       Computers and Accessories     1251.36
# 15  15      Fitness Tracker  Mobile Devices and Accessories     2997.29
# 16  30         Gaming Chair                Gaming Equipment      417.16
# 17  34           HDMI Cable                          Cables     1710.84
# 19  49            Headphone                 Audio Equipment     1317.56
# 20  19             Keyboard       Computers and Accessories      604.18
# 21   2               Laptop       Computers and Accessories     1851.32
# 23  23        Micro SD Card                 Storage Devices     3238.23
# 24  36                Modem                             NaN     3256.88
# 25  20                Mouse       Computers and Accessories     1333.04
# 26  38      Office Software   Printers and Office Equipment     3454.82
# 27  32     Portable Charger  Mobile Devices and Accessories     1523.27
# 28  39          Power Strip   Printers and Office Equipment     3344.90
# 30  47              Printer   Printers and Office Equipment     3704.16
# 31  17          Smart Watch        Televisions and Displays      312.88
# 33   4           Smartphone  Mobile Devices and Accessories      965.20
# 36  50              Speaker                 Audio Equipment     4453.90
# 37  33      Surge Protector   Printers and Office Equipment      488.39
# 39  46               Tablet  Mobile Devices and Accessories     1606.65
# 40   1           Television        Televisions and Displays      356.81
# 43  22      USB Flash Drive                             NaN     1150.87
# 44  13           Video Game                             NaN     1890.03
# 45  12   Video Game Console                Gaming Equipment      689.61
# 46  41           VR Headset                             NaN     1905.01
# 47  29               Webcam   Printers and Office Equipment     4227.36
# 48  35         Wi-Fi Router               Network Equipment     3812.53
# 49  31     Wireless Charger  Mobile Devices and Accessories      241.54
#
#     stock_quantity item_brand  item_availability  info level
# 0              NaN       Bose              False           6
# 1              NaN        NaN              False           5
# 2            704.0       ASUS               True           7
# 3            870.0       Bose               True           7
# 4            458.0  Microsoft               True           7
# 7           1205.0       Bose               True           7
# 8            550.0     Lenovo               True           7
# 9            334.0         HP               True           7
# 11           443.0    Samsung               True           7
# 14          1013.0  Microsoft               True           7
# 15           956.0      Apple               True           7
# 16           704.0    Samsung               True           7
# 17           869.0        JBL               True           7
# 19             NaN       Sony              False           6
# 20             NaN  Panasonic              False           6
# 21           493.0         HP               True           7
# 23           663.0       Sony               True           7
# 24           673.0       Bose               True           6
# 25           881.0   Logitech               True           7
# 26           643.0        JBL               True           7
# 27           192.0         HP               True           7
# 28          1211.0         HP               True           7
# 30           239.0    Toshiba               True           7
# 31           685.0      Canon               True           7
# 33           201.0       Bose               True           7
# 36           937.0   Logitech               True           7
# 37           800.0       ASUS               True           7
# 39           267.0         HP               True           7
# 40          1009.0        JBL               True           7
# 43          1251.0  Panasonic               True           6
# 44           681.0     Lenovo               True           6
# 45           753.0  Microsoft               True           7
# 46          1367.0        JBL               True           6
# 47           596.0       Dell               True           7
# 48            14.0  Microsoft               True           7
# 49           951.0     Lenovo               True           7

# %%
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#7 Bonus

keptRemoved = removed.merge(kept, on="item_name", suffixes = ('_removed', '_kept'))
keptRemovedDict = dict(zip(keptRemoved['id_removed'], keptRemoved['id_kept']))
keptRemovedDict
orderItem.replace(keptRemovedDict, inplace = True)

# %%
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#8

customers['nan count'] = customers.isna().sum(axis = 1)
customers.sort_values('nan count', ascending = False)
customersRemoved = customers[customers['nan count'] >= 3]
customers.drop(customersRemoved.index, inplace = True)
customers.sort_values('nan count', ascending = False)
# Out:
#       id first_name    last_name  gender   age   nationallity joining_date  \
# 406  407      Sharl     Ashpital     NaN  57.0         Isreal          NaN
# 137  138     Ellary       Ledner     NaN  63.0           Peru          NaN
# 465  466   Natassia     Bransden  Female   NaN  United States          NaN
# 216  217    Anderea        Rawne     NaN  29.0         Isreal          NaN
# 204  205    Christy    Shoebrook  Female   NaN  United States          NaN
# ..   ...        ...          ...     ...   ...            ...          ...
# 194  195     Perren     Knowlton    Male  28.0  United States   06/06/2021
# 192  193      Fayre  Westmancoat  Female  38.0      Argentina   15/05/2021
# 191  192      Anson      Mepsted    Male  37.0    South Korea   14/06/2022
# 189  190    Hermina        Henri  Female  61.0  United States   07/01/2022
# 499  500   Richardo     O'Criane    Male  32.0  United States   06/08/2021
#
#      phone_number                           email  nan count
# 406  289-139-5295              sashpitalba@ca.gov          2
# 137  343-500-4046           eledner3t@latimes.com          2
# 465  353-550-7048                nbransdencx@g.co          2
# 216  318-316-2247                  arawne60@ow.ly          2
# 204  169-347-2697            cshoebrook5o@ask.com          2
# ..            ...                             ...        ...
# 194  456-605-7235  pknowlton5e@barnesandnoble.com          0
# 192  270-346-7256           fwestmancoat5c@i2i.jp          0
# 191  209-197-2981        amepsted5b@wikimedia.org          0
# 189  986-187-7991        hhenri59@theatlantic.com          0
# 499  796-438-2219        rocrianedv@geocities.com          0
#
# [494 rows x 10 columns]

# %%
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#9 Bonus

# orderItem.drop(customersRemoved.index, inplace = True)
# orderItem[orderItem['id'].isin(customersRemoved.index)]

ordersMerged = orderItem.merge(orders, on = 'order_id')
ordersToDelete = ordersMerged[ordersMerged['customer_id'].isin(customersRemoved['id'])]['order_id'].unique()
orderItem = orderItem[~orderItem['order_id'].isin(ordersToDelete)]

orderItem

#orderItem
# display(customersRemoved)
# ordersMerged
# ordersToDelete

#orderItem[orderItem['order_id'].isin(ordersToDelete)]

# ordersToDelete
# Out:
# Empty DataFrame
# Columns: [id, order_id, item_id, quantity]
# Index: []

# %%
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#Part D

#1
items["item_price"].mean()

#2


customerOrders = customers.merge(orders, left_on = 'id', right_on = 'customer_id')

maxOrder = customerOrders['id'].value_counts().max()

customerOrders['amount'] = customerOrders['id'].value_counts()

customerOrders[customerOrders['amount'] == maxOrder]

#3
totalMerged = orderItem.merge(items, left_on = 'item_id', right_on = 'id')
orderItem['total price'] = totalMerged['quantity'] * totalMerged['item_price']

#4
orderItem

#5
orderItem['total price'].max()
orderItem['total price'].min()
orderItem['total price'].mean()

#6

pivot = pd.pivot_table(
    customers,                 
    columns='gender',  # Columns will be the unique values in 'Product'
    values='id',     # Values to aggregate (here, the 'Sales' column)
    index='nationallity',       # Rows will be grouped by 'Date'
    aggfunc= 'sum'       # Aggregation function (summing the sales values)
)

pivot
# Out:
# gender         Agender  Bigender  Female  Genderfluid  Genderqueer     Male  \
# nationallity
# Argentina         83.0       NaN  2787.0        139.0          NaN   2660.0
# Brazil             NaN       NaN  1218.0          NaN          NaN   5004.0
# Chile            213.0       NaN  3338.0          NaN          NaN   2073.0
# China              NaN       NaN   793.0        485.0        149.0   2152.0
# France           463.0       NaN  3746.0        413.0          NaN   1647.0
# Germany            NaN       NaN  3428.0          NaN          NaN   1291.0
# India            306.0       NaN  2208.0          NaN          NaN   3807.0
# Isreal           616.0     244.0  4378.0       1366.0        292.0   6907.0
# Italy              NaN       NaN  3837.0          NaN        514.0   2967.0
# Japan            576.0       NaN  3814.0          NaN          NaN   1745.0
# Peru             242.0       NaN  2791.0        208.0          NaN   1082.0
# South Korea      284.0     345.0  3643.0          NaN          NaN   2595.0
# Spain            288.0       NaN  1129.0        105.0          NaN   3257.0
# Sweden             NaN       NaN  2682.0        671.0          NaN    994.0
# United States    335.0     459.0  9434.0          NaN          NaN  11950.0
#
# gender         Non-binary  Polygender
# nationallity
# Argentina             NaN        82.0
# Brazil              699.0       352.0
# Chile                 NaN         NaN
# China                 NaN       154.0
# France                NaN         NaN
# Germany               NaN       212.0
# India                 NaN         NaN
# Isreal                NaN       695.0
# Italy                 NaN         NaN
# Japan                 NaN         NaN
# Peru                  NaN         NaN
# South Korea         416.0         NaN
# Spain                 NaN         NaN
# Sweden                NaN         NaN
# United States       196.0         NaN

# %%
customers = pd.read_csv("customers.csv")
items = pd.read_csv("items.csv")
orderItem = pd.read_csv("order_item.csv")
orders = pd.read_csv("orders.csv")

#Graphs
